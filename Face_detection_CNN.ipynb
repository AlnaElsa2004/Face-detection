# %%
import cv2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import dlib

# %% [markdown]
# ### Detecting faces with CNN (Convolutional Neural Networks)

# %%
image = cv2.imread('/content/my_new_folder/people2.jpg')
cnn_detector = dlib.cnn_face_detection_model_v1('/content/my_new_folder/mmod_human_face_detector.dat')

# %%
detections = cnn_detector(image, 1)
for face in detections:
  l, t, r, b, c = face.rect.left(), face.rect.top(), face.rect.right(), face.rect.bottom(), face.confidence
  print(c)
  cv2.rectangle(image, (l, t), (r, b), (255, 255, 0), 2)
cv2_imshow(image)
# Out:
# 1.1440614461898804
# 1.137049913406372
# 1.1278995275497437
# 1.1200283765792847
# 1.1149375438690186
# 1.1131553649902344
# 1.0975688695907593
# 1.0942121744155884
# 1.085315227508545
# 1.0801889896392822
# 1.0800762176513672
# 1.0784764289855957
# 1.066403865814209
# 1.0641791820526123
# <PIL.Image.Image image mode=RGB size=1023x537 at 0x7FDE40BF37F0>

# %% [markdown]
# ### Haarcascade x HOG x CNN

# %% [markdown]
# #### Haarcascade

# %%
image.shape
# Out:
# (294, 626, 3)

# %%
image = cv2.imread('/content/my_new_folder/people3.jpg')
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
haarcascade_detector = cv2.CascadeClassifier('/content/my_new_folder/haarcascade_frontalface_default.xml')
detections = haarcascade_detector.detectMultiScale(image_gray, scaleFactor = 1.001, minNeighbors=5, minSize = (5,5))
for (x, y, w, h) in detections:
  cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=626x294 at 0x7FDE40C41EF0>

# %% [markdown]
# #### HOG

# %%
image = cv2.imread('/content/my_new_folder/people3.jpg')
face_detector_hog = dlib.get_frontal_face_detector()
detections = face_detector_hog(image, 4)
for face in detections:
    l, t, r, b = (face.left(), face.top(), face.right(), face.bottom())
    cv2.rectangle(image, (l, t), (r, b), (0, 255, 255), 2)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=626x294 at 0x7FDE40C073C8>

# %% [markdown]
# #### CNN

# %%
image = cv2.imread('/content/my_new_folder/people3.jpg')
cnn_detector = dlib.cnn_face_detection_model_v1('/content/my_new_folder/mmod_human_face_detector.dat')
detections = cnn_detector(image, 4)
for face in detections:
  l, t, r, b, c = face.rect.left(), face.rect.top(), face.rect.right(), face.rect.bottom(), face.confidence
  print(c)
  cv2.rectangle(image, (l, t), (r, b), (255, 255, 0), 2)
cv2_imshow(image)
# Out:
# 0.4463871121406555
# 0.08115974068641663
# <PIL.Image.Image image mode=RGB size=626x294 at 0x7FDE40BFA940>
